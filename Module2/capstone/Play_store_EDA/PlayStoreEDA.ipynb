# %% [markdown]
# # **Project Name**    -  **Play Store EDA**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Rakshit Pandey**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
#
# ### Introduction:
# The Play Store apps data provides valuable insights for app-making businesses aiming for success in the Android market. Understanding user preferences and factors driving app engagement is crucial for developers to improve app quality and user satisfaction. In this exploratory data analysis (EDA) project, we aim to delve into the Play Store apps dataset and customer reviews to uncover key insights that can guide app development strategies and enhance user experience.
#
# ### Dataset Description:
# The dataset comprises customer reviews of Android apps, containing fields such as review ID, username, review text, rating, upvotes, version, and timestamps. Each review offers valuable feedback from users, providing insights into user sentiment, satisfaction, and areas for improvement.
#
# ### Objectives:
#
# 1. **Explore User Reviews**: Analyze user reviews to understand sentiment and identify common themes.
# 2. **Investigate App Ratings**: Examine the distribution of app ratings and identify factors influencing positive and negative ratings.
# 3. **Discover Trends Over Time**: Explore trends in review counts, app versions, and user engagement.
# 4. **Compare Free vs. Paid Apps**: Compare the performance and user sentiment of free and paid apps.
# 5. **Visualize Insights**: Present key insights through various visualizations to aid in interpretation and decision-making.
#
# ### Methodology:
#
# 1. **Data Loading and Cleaning**: Load the dataset and perform data cleaning to handle missing values and inconsistencies.
# 2. **Understanding Variables**: Explore dataset columns, summary statistics, and unique values to understand the variables.
# 3. **Data Wrangling**: Prepare the data for analysis by performing necessary manipulations and transformations.
# 4. **Data Visualization and Storytelling**:
#    - Create visualizations to understand relationships between variables and uncover insights.
#    - Utilize storytelling to interpret findings and draw actionable insights.
# 5. **Key Findings and Recommendations**: Summarize key findings and provide recommendations for app developers and stakeholders.
#
#
# ### Key Findings:
#
#     Key findings will come here
#
# ---

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.
#
# https://github.com/pandey-rakshit/almabetter/tree/main/Module2/capstone/Play_store_EDA

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
#
# ### Business Context:
# The Android app market is highly competitive, with millions of apps available on the Google Play Store. For app developers and businesses, understanding user preferences and factors influencing app engagement is crucial for success. User reviews play a significant role in shaping the reputation and popularity of apps, while app ratings provide valuable feedback on user satisfaction. However, navigating through vast amounts of data to extract meaningful insights can be challenging.
#
# ### Problem:
# The challenge is to analyze the Play Store apps dataset and customer reviews to uncover key factors responsible for app engagement and success. The primary goal is to provide actionable insights for developers to improve their apps and enhance user satisfaction. Specific objectives include:
#
# 1. **Understanding User Sentiment**: Analyze user reviews to understand sentiment and identify common themes, issues, and preferences.
# 2. **Investigating App Ratings**: Examine the distribution of app ratings and identify factors influencing positive and negative ratings.
# 3. **Discovering Trends Over Time**: Explore trends in review counts, app versions, and user engagement to identify patterns and fluctuations.
# 4. **Comparing Free vs. Paid Apps**: Compare the performance and user sentiment of free and paid apps to understand their impact on user satisfaction.
# 5. **Visualizing Insights**: Present key insights through various visualizations to aid in interpretation and decision-making.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.
#
# The ultimate goal is to provide actionable insights for app developers and stakeholders to improve app quality, user experience, and overall success in the Android app market. By understanding user sentiment, app ratings, and trends over time, developers can make informed decisions to enhance their apps, attract more users, and increase user satisfaction.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## Dependencies

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

def load_dataset(file_path):
    """
    Load the dataset from the given file path.
    
    Args:
    - file_path (str): Path to the CSV file
    
    Returns:
    - df (DataFrame): Loaded DataFrame
    """
    try:
        df = pd.read_csv(file_path)
        return df
    except FileNotFoundError:
        print("File not found. Please provide the correct file path.")
        return None

# %% [markdown]
# ### Dataset Wrangling

# %% [markdown]
# #### Handling Missing Values

# %%
# handling missing values

def handle_missing_values(df):
    """
    Handle missing values in the DataFrame.
    
    Args:
    - df (DataFrame): Input DataFrame
    
    Returns:
    - df (DataFrame): DataFrame with missing values handled
    """
    # Check missing values
    print(f"Missing values before handling: \n{df.isnull().sum()}\n")
    
    # Drop rows with missing values
    df.dropna(inplace=True)
    
    # Check missing values after handling
    print(f"\nMissing values after handling: \n{df.isnull().sum()}\n")
    
    return df

# %% [markdown]
# #### Handling Duplicates Values

# %%
# Handling Duplicates Values

def handle_duplicates(df):
    """
    Handle duplicate rows in the DataFrame.
    
    Args:
    - df (DataFrame): Input DataFrame
    
    Returns:
    - df (DataFrame): DataFrame with duplicates removed
    """
    # Check duplicate rows
    print(f"Duplicate rows before handling: \n{df.duplicated().sum()}\n")
    
    # Remove duplicate rows
    df.drop_duplicates(inplace=True)
    
    # Check duplicate rows after handling
    print(f"Duplicate rows after handling: \n{df.duplicated().sum()}\n")
    
    return df

# %% [markdown]
# #### Datatype casting

# %%
# convert data types | datatype casting

def convert_data_types(df, column_dtype_map):
    """
    Convert columns to specified data types in the DataFrame.
    
    Args:
    - df (DataFrame): Input DataFrame
    - column_dtype_map (dict): Dictionary mapping column names to target data types
    
    Returns:
    - df (DataFrame): DataFrame with converted data types
    """
    # Iterate through each column and its target data type
    for column, dtype in column_dtype_map.items():
        # Convert column to specified data type
        df[column] = df[column].astype(dtype)
    
    return df

# %% [markdown]
# #### Size conversion

# %%
# size conversion : KB to MB

def convert_size_to_mb(size):
    """
    Convert size strings to megabytes and handle special cases.

    Args:
    - size (str): Size string (e.g., '45MB', '1000KB', 'Varies with device')

    Returns:
    - float: Size in megabytes, or np.nan if 'Varies with device'
    """
    # Define a mapping dictionary for unit conversion factors
    units = {
        'k': 1 / 1024,  # kilobyte to megabyte
        'kb': 1 / 1024,  # kilobyte to megabyte
        'm': 1,         # megabyte to megabyte
        'mb': 1,        # megabyte to megabyte
        'g': 1024,      # gigabyte to megabyte
        'gb': 1024      # gigabyte to megabyte
    }
    
    try:
        size = size.lower()  # Convert to lowercase for case insensitivity
        # Iterate over the units and their conversion factors
        for unit, factor in units.items():
            # Check if the size string ends with the current unit
            if size.endswith(unit):
                # If yes, remove the unit and convert the size to megabytes
                return float(size[:-len(unit)]) * factor
        # If the size does not end with any recognized unit, treat it as bytes
        return float(size) / (1024 * 1024)
    except ValueError:
        # If conversion fails due to invalid input, return NaN
        return np.nan

# %% [markdown]
# ### Data Visualization

# %%
# chart visualzation function
def visualize_chart(plot_function, title, xlabel, ylabel, x, y = None, **kwargs):
    """
    Create a custom visualization chart.
    
    Parameters:
    - plot_function (function): Function for plotting, e.g., sns.scatterplot, sns.lineplot, sns.barplot.
    - title (str): Title of the chart.
    - xlabel (str): Label for the x-axis.
    - ylabel (str): Label for the y-axis.
    - x (array-like): Data for the x-axis.
    - y (array-like, optional): Data for the y-axis.
    - **kwargs: Additional keyword arguments to be passed to the plotting function.
    
    Returns:
    - fig (matplotlib.figure.Figure): The created figure object.
    """
    plt.figure(figsize=(10, 6))

    # Construct dictionary with arguments
    plot_args = {'x': x}
    if y is not None:
        plot_args['y'] = y
    
    # Add additional keyword arguments
    plot_args.update(kwargs)

    # Call plotting function with dynamic arguments
    plot_function(**plot_args)
    
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(rotation=45)
    
    fig = plt.gcf()
    
    return fig

# %%
# Define a dictionary to map chart types to plotting functions

plot_functions = {
    'scatter': sns.scatterplot,
    'line': sns.lineplot,
    'bar': sns.barplot,
    'hist': plt.hist,
    'pie': plt.pie,
    'count': sns.countplot
}

# %% [markdown]
# # Play Store Data Analysis

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Read Data File

# %%
# read_csv file "Play Store Data.csv"
play_store_file = 'https://raw.githubusercontent.com/pandey-rakshit/almabetter/main/Module2/capstone/Play_store_EDA/data/Play%20Store%20Data.csv'

# loading dataset - play_store_df : DataFrame
play_store_df = load_dataset(play_store_file)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
play_store_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# Renaming df columns: Replacing space by underscore "_"
play_store_df.columns = play_store_df.columns.str.replace(' ', '_')
play_store_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Current_Ver',
#        'Android_Ver'],
#       dtype='object')

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
play_store_df.shape
# Out:
# (10841, 13)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
play_store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content_Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last_Updated    10841 non-null  object
#  11  Current_Ver     10833 non-null  object
#  12  Android_Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

play_store_df.duplicated().sum()
# Out:
# 483

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

play_store_missing_value_counts = play_store_df.isna().sum()
play_store_missing_value_counts
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content_Rating       1
# Genres               0
# Last_Updated         0
# Current_Ver          8
# Android_Ver          3
# dtype: int64

# %%
# Chart - 1 - Visualizing the missing values

# constants used in visualizing the missing values

title = 'Missing Values Chart : Play Store Data'
xlabel = 'Dataset Columns'
ylabel = 'Missing Values Count'

x = play_store_missing_value_counts.index
y = play_store_missing_value_counts.values

# visualize_chart function calling to visualize the missing values
fig = visualize_chart(plot_functions['bar'], title, xlabel, ylabel, 
x, y)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# **Bar Chart**
#
# A bar chart is chosen to visualize missing values count because it clearly shows the frequency of missing data for each column, making it easy to compare.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The chart reveals that the 'Rating' column has the highest number of missing values, followed by 'Current_Ver' and 'Android_Ver'.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# - Yes, identifying columns with missing values helps prioritize data cleaning efforts, ensuring accurate analysis and decision-making.
# - High missing values in 'Rating' might hinder accurate assessment of app quality, potentially impacting customer satisfaction analysis.

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here
#
# #### Play Store Data
#
# 1. **Size and Structure**:
#    - The DataFrame has 10,841 rows and 13 columns.
#    - Each row represents an entry (or record) about a mobile app.
#    - The columns are:
#      - App: Name of the application.
#      - Category: Category of the application.
#      - Rating: Average user rating of the application.
#      - Reviews: Number of user reviews for the application.
#      - Size: Size of the application.
#      - Installs: Number of downloads/installs of the application.
#      - Type: Whether the application is free or paid.
#      - Price: Price of the application.
#      - Content Rating: Content rating of the application.
#      - Genres: Genre(s) of the application.
#      - Last Updated: Date when the application was last updated.
#      - Current Ver: Current version of the application.
#      - Android Ver: Minimum required Android version.
#
# 2. **Data Types and Missing Values**:
#    - The 'Rating' column is of float type.
#    - The 'Reviews', 'Size', 'Installs', 'Price', 'Last Updated', 'Current Ver', and 'Android Ver' columns are of object type.
#    - There are missing values in the DataFrame:
#      - 'Rating' column has 1474 missing values.
#      - 'Type', 'Content Rating', 'Current Ver', and 'Android Ver' columns have 1, 1, 8, and 3 missing values respectively.
#
# 3. **Duplicates**:
#    - There are 483 duplicate entries in the DataFrame.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
play_store_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Current_Ver',
#        'Android_Ver'],
#       dtype='object')

# %%
# Dataset Describe
play_store_df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here
#
# #### Play Store Data
#
# 1. **Outliers**:
#    - An outlier with a rating of 19 was identified, indicating potential data entry errors or data quality issues.
#    - It is important to investigate and potentially correct or remove this outlier to avoid skewing the analysis.
#
# 2. **Missing Values**:
#    - The 'Rating' column has 1474 missing values.
#    - Missing values should be handled appropriately, either by imputation or by removing rows with missing values.
#    - Addressing missing values is crucial for accurate analysis and interpretation.
#
# 3. **Duplicated Data**:
#    - There are 483 duplicated entries in the dataset.
#    - Duplicates need to be removed to prevent overcounting and ensure accuracy in the analysis.
#
# 4. **Summary**:
#    - The 'Rating' column has an average rating of approximately 4.19 out of 5, with a moderate level of variability indicated by a standard deviation of around 0.54.
#    - The presence of an outlier with a rating of 19 and missing values in the 'Rating' column, along with duplicated entries, need to be addressed for accurate analysis.
#    - Addressing outliers, missing values, and duplicates is crucial for a reliable interpretation of the data.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable. -- Play Store Data
play_store_df.nunique()
# Out:
# App               9660
# Category            34
# Rating              40
# Reviews           6002
# Size               462
# Installs            22
# Type                 3
# Price               93
# Content_Rating       6
# Genres             120
# Last_Updated      1378
# Current_Ver       2832
# Android_Ver         33
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Handle missing values
play_store_df = handle_missing_values(play_store_df)
# Out:
# Missing values before handling:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content_Rating       1
# Genres               0
# Last_Updated         0
# Current_Ver          8
# Android_Ver          3
# dtype: int64
#
#
# Missing values after handling:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content_Rating    0
# Genres            0
# Last_Updated      0
# Current_Ver       0
# Android_Ver       0
# dtype: int64

# %%
# Handle duplicates values
play_store_df = handle_duplicates(play_store_df)
# Out:
# Duplicate rows before handling:
# 474
#
# Duplicate rows after handling:
# 0

# %%
play_store_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content_Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last_Updated         Current_Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# #### Data Exploring & Type Casting

# %% [markdown]
# ##### Columns - Size

# %%
# checking unique Size 
play_store_df['Size'].str[-1].unique()

# findings - 
# M stands for Megabyte
# k stands for kilobyte
# e is the third variable
# Out:
# array(['M', 'e', 'k'], dtype=object)

# %%
# checking the third variable that ends with 'e'
play_store_df['Size'][play_store_df['Size'].str.endswith('e')].iloc[0]
# Out:
# 'Varies with device'

# %%
# converting the Size to Megabyte 
play_store_df['Size'] = play_store_df['Size'].apply(convert_size_to_mb)

# %%
# replacing the nan or None value with the mean 
play_store_df['Size'].replace(np.nan, round(play_store_df['Size'].mean(), 2), inplace=True)
play_store_df['Size'].head()
# Out:
# 0    19.0
# 1    14.0
# 2     8.7
# 3    25.0
# 4     2.8
# Name: Size, dtype: float64

# %% [markdown]
# ##### Columns - Installs

# %%
play_store_df['Installs'] = play_store_df['Installs'].str.replace(',', '', regex=False).str.replace('+', '', regex=False)
play_store_df['Installs'].head()
# Out:
# 0       10000
# 1      500000
# 2     5000000
# 3    50000000
# 4      100000
# Name: Installs, dtype: object

# %% [markdown]
# ##### Columns - Price

# %%
# Convert 'Price' to numeric by removing '$'
play_store_df['Price'] = play_store_df['Price'].str.replace('$', '', regex=False)
play_store_df['Price'][play_store_df['Price'] != '0'].head()
# Out:
# 234    4.99
# 235    4.99
# 427    3.99
# 476    3.99
# 477    6.99
# Name: Price, dtype: object

# %% [markdown]
# ##### Type Casting

# %%
# Define the column dtype map
column_dtype_map = {
    'Reviews': int,
    'Installs': int,
    'Price': float,
    'Last_Updated': 'datetime64[ns]'
}

# Apply the data type conversion
play_store_df = convert_data_types(play_store_df, column_dtype_map)

# %% [markdown]
# #### FINAL data

# %%
play_store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8886 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8886 non-null   object
#  1   Category        8886 non-null   object
#  2   Rating          8886 non-null   float64
#  3   Reviews         8886 non-null   int64
#  4   Size            8886 non-null   float64
#  5   Installs        8886 non-null   int64
#  6   Type            8886 non-null   object
#  7   Price           8886 non-null   float64
#  8   Content_Rating  8886 non-null   object
#  9   Genres          8886 non-null   object
#  10  Last_Updated    8886 non-null   datetime64[ns]
#  11  Current_Ver     8886 non-null   object
#  12  Android_Ver     8886 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(7)
# memory usage: 971.9+ KB

# %%
play_store_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content_Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres Last_Updated         Current_Ver   Android_Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %% [markdown]
# #### Analysis

# %% [markdown]
# #### 1. Categories and App Count
# 1. What are the top 5 categories with the least number of apps?
# 2. How does the distribution of app counts vary among the top 10 categories?
# 3. Are there any categories that only have free apps?
# 4. Which categories have the most balanced ratio of free to paid apps?
#
# #### 2. Reviews and Ratings
# 5. What is the average number of reviews per category?
# 6. Are there categories where the majority of apps have high ratings (4+ stars)?
# 7. What is the distribution of reviews across different rating levels?
# 8. How do the number of reviews impact the average rating of an app?
# 9. What is the most common rating given to apps in the "Game" category?
# 10. How do ratings differ between newly updated apps and older apps?
#
# #### 3. App Size and Installs
# 11. What is the average size of apps within each category?
# 12. How does app size influence the number of installs?
# 13. Are there any categories where larger apps (50MB+) are more popular?
# 14. What is the distribution of app sizes in the top 3 categories with the most installs?
# 15. How does the average app size compare between free and paid apps?
#
# #### 4. Content and Genre Analysis
# 16. What are the most frequent sub-genres within the "Family" category?
# 17. How does the content rating (e.g., Everyone, Teen) affect the number of installs?
# 18. Are there specific genres that consistently receive higher ratings?
# 19. How does the distribution of genres differ between free and paid apps?
# 20. What are the least common genres in the dataset?
#
# #### 5. Pricing and Business Model
# 21. How does the average price of paid apps vary across categories?
#
# #### 6. Impact of Free vs. Paid Apps on Installs
# 22. How does the average number of installs differ between free and paid apps across different categories?

# %% [markdown]
# #### 1. Categories and App Count

# %% [markdown]
# ##### 1. What are the top 5 categories with the least number of apps?

# %%
# What are the top 5 categories with the least number of apps?

top_5_least_categories = play_store_df['Category'].value_counts().nsmallest(5)
top_5_least_categories
# Out:
# BEAUTY            42
# EVENTS            45
# PARENTING         50
# COMICS            58
# ART_AND_DESIGN    61
# Name: Category, dtype: int64

# %% [markdown]
# ##### 2. How does the distribution of app counts vary among the top 10 categories?

# %%
# Find the distribution of app counts for the top 10 categories

top_10_categories = play_store_df['Category'].value_counts().nlargest(10)
top_10_categories
# Out:
# FAMILY             1717
# GAME               1074
# TOOLS               733
# PRODUCTIVITY        334
# FINANCE             317
# PERSONALIZATION     308
# COMMUNICATION       307
# LIFESTYLE           305
# PHOTOGRAPHY         304
# MEDICAL             302
# Name: Category, dtype: int64

# %% [markdown]
# ##### 3. Are there any categories that only have free apps?

# %%
# Check for categories that only have free apps

categories_with_only_free_apps = play_store_df[play_store_df['Type'] == 'Free']['Category'].value_counts()
categories_with_paid_apps = play_store_df[play_store_df['Type'] == 'Paid']['Category'].unique()
only_free_categories = categories_with_only_free_apps[~categories_with_only_free_apps.index.isin(categories_with_paid_apps)]
only_free_categories
# Out:
# HOUSE_AND_HOME        68
# LIBRARIES_AND_DEMO    64
# COMICS                58
# EVENTS                45
# BEAUTY                42
# Name: Category, dtype: int64

# %% [markdown]
# ##### 4. Which categories have the most balanced ratio of free to paid apps?

# %%
# Calculate the ratio of free to paid apps per category

category_type_counts = play_store_df.groupby(['Category', 'Type']).size().unstack(fill_value=0)
category_type_counts['ratio'] = category_type_counts['Free'] / category_type_counts['Paid']
balanced_categories = category_type_counts.sort_values('ratio', key=lambda x: abs(x-1)).head(10)
balanced_categories
# Out:
# Type             Free  Paid      ratio
# Category
# MEDICAL           238    64   3.718750
# PERSONALIZATION   243    65   3.738462
# WEATHER            68     7   9.714286
# FAMILY           1560   157   9.936306
# TOOLS             670    63  10.634921
# SPORTS            264    22  12.000000
# GAME              997    77  12.948052
# COMMUNICATION     285    22  12.954545
# LIFESTYLE         287    18  15.944444
# PRODUCTIVITY      316    18  17.555556

# %% [markdown]
# #### 2. Reviews and Ratings

# %% [markdown]
# ##### 5. What is the average number of reviews per category?

# %%
# Calculate the average number of reviews per category
average_reviews_per_category = play_store_df.groupby('Category')['Reviews'].mean()
average_reviews_per_category
# Out:
# Category
# ART_AND_DESIGN         2.810356e+04
# AUTO_AND_VEHICLES      1.594014e+04
# BEAUTY                 9.407929e+03
# BOOKS_AND_REFERENCE    1.235752e+05
# BUSINESS               4.576928e+04
# COMICS                 5.830940e+04
# COMMUNICATION          1.958544e+06
# DATING                 3.487525e+04
# EDUCATION              1.795715e+05
# ENTERTAINMENT          4.285650e+05
# EVENTS                 3.568667e+03
# FAMILY                 2.310824e+05
# FINANCE                5.362640e+04
# FOOD_AND_DRINK         7.237033e+04
# GAME                   1.318002e+06
# HEALTH_AND_FITNESS     1.177293e+05
# HOUSE_AND_HOME         4.109399e+04
# LIBRARIES_AND_DEMO     1.583422e+04
# LIFESTYLE              4.203134e+04
# MAPS_AND_NAVIGATION    2.472505e+05
# MEDICAL                4.623930e+03
# NEWS_AND_MAGAZINES     1.787145e+05
# PARENTING              1.907218e+04
# PERSONALIZATION        2.441312e+05
# PHOTOGRAPHY            6.720308e+05
# PRODUCTIVITY           3.070486e+05
# ...

# %% [markdown]
# ##### 6. Are there categories where the majority of apps have high ratings (4+ stars)?

# %%
# Find categories where the majority of apps have ratings of 4 or higher

high_rating_categories = play_store_df[play_store_df['Rating'] >= 4]['Category'].value_counts()
total_apps_per_category = play_store_df['Category'].value_counts()
high_rating_percentage = round((high_rating_categories / total_apps_per_category) * 100, 2)
categories_majority_high_ratings = high_rating_percentage[high_rating_percentage > 50].head(10)
categories_majority_high_ratings
# Out:
# ART_AND_DESIGN         90.16
# AUTO_AND_VEHICLES      75.34
# BEAUTY                 83.33
# BOOKS_AND_REFERENCE    83.62
# BUSINESS               71.48
# COMICS                 68.97
# COMMUNICATION          80.46
# DATING                 63.52
# EDUCATION              95.35
# ENTERTAINMENT          73.87
# Name: Category, dtype: float64

# %% [markdown]
# ##### 7. What is the distribution of reviews across different rating levels?

# %%
# Distribution of reviews across different rating levels

rating_review_distribution = play_store_df.groupby('Rating')['Reviews'].sum()
rating_review_distribution = rating_review_distribution.sort_values(ascending=False)
rating_review_distribution.head(10)
# Out:
# Rating
# 4.5    1158893777
# 4.4     868505306
# 4.6     675532724
# 4.3     600865514
# 4.1     228915549
# 4.0     223602758
# 4.2     192300285
# 4.7     189812069
# 4.8      23349249
# 3.9      13564710
# Name: Reviews, dtype: int64

# %% [markdown]
# ##### 8. How do the number of reviews impact the average rating of an app?

# %%
# Analyze how the number of reviews impact the average rating of an app

reviews_rating_correlation = play_store_df[['Reviews', 'Rating']].corr()
reviews_rating_correlation
# Out:
#           Reviews    Rating
# Reviews  1.000000  0.068724
# Rating   0.068724  1.000000

# %% [markdown]
# ##### 9. What is the most common rating given to apps in the "Game" category?

# %%
# Most common rating in the "Game" category

most_common_game_rating = play_store_df[play_store_df['Category'] == 'GAME']['Rating'].mode()[0]
most_common_game_rating
# Out:
# 4.5

# %% [markdown]
# ##### 10. How do ratings differ between newly updated apps and older apps?

# %%
# Compare ratings between newly updated and older apps

play_store_df['Last_Updated'] = pd.to_datetime(play_store_df['Last_Updated'])
median_update_date = play_store_df['Last_Updated'].median()

newly_updated_apps = play_store_df[play_store_df['Last_Updated'] >= median_update_date]
newly_updated_avg_rating = newly_updated_apps['Rating'].mean()

older_apps = play_store_df[play_store_df['Last_Updated'] < median_update_date]
older_apps_avg_rating = older_apps['Rating'].mean()

newly_updated_avg_rating, older_apps_avg_rating
# Out:
# (4.2671752299753205, 4.1082411379543915)

# %% [markdown]
# #### 3. App Size and Installs

# %% [markdown]
# ##### 11. What is the average size of apps within each category?

# %%
# Calculate the average size of apps within each category

average_size_per_category = play_store_df.groupby('Category')['Size'].mean()
average_size_per_category
# Out:
# Category
# ART_AND_DESIGN         13.422623
# AUTO_AND_VEHICLES      21.708168
# BEAUTY                 16.376190
# BOOKS_AND_REFERENCE    15.866831
# BUSINESS               15.468588
# COMICS                 14.647730
# COMMUNICATION          15.766202
# DATING                 18.182264
# EDUCATION              20.753462
# ENTERTAINMENT          22.686847
# EVENTS                 15.727693
# FAMILY                 29.234040
# FINANCE                19.317763
# FOOD_AND_DRINK         23.763585
# GAME                   42.709791
# HEALTH_AND_FITNESS     22.985350
# HOUSE_AND_HOME         19.023235
# LIBRARIES_AND_DEMO     13.168051
# LIFESTYLE              16.273622
# MAPS_AND_NAVIGATION    18.690809
# MEDICAL                19.537704
# NEWS_AND_MAGAZINES     15.103368
# PARENTING              21.721200
# PERSONALIZATION        12.776650
# PHOTOGRAPHY            18.520580
# PRODUCTIVITY           15.841176
# SHOPPING               18.158067
# SOCIAL                 19.630863
# ...

# %% [markdown]
# ##### 12. How does app size influence the number of installs?

# %%
# Calculate correlation between Size and Installs
correlation_size_installs = play_store_df['Size'].corr(play_store_df['Installs'])
correlation_size_installs
# Out:
# 0.08178844692371384

# %% [markdown]
# ##### 13. Are there any categories where larger apps (50MB+) are more popular?

# %%
# Calculate the proportion of installs for apps with sizes > 50MB across different categories

large_apps_category = play_store_df[play_store_df['Size'] > 50]
install_proportion_large_apps = (large_apps_category.groupby('Category')['Installs'].sum() / play_store_df.groupby('Category')['Installs'].sum()).sort_values(ascending=False)
install_proportion_large_apps
# Out:
# Category
# GAME                   0.624625
# HEALTH_AND_FITNESS     0.426311
# FAMILY                 0.377533
# PARENTING              0.355764
# SPORTS                 0.328015
# LIFESTYLE              0.221883
# PRODUCTIVITY           0.121166
# ENTERTAINMENT          0.086413
# PHOTOGRAPHY            0.080854
# FINANCE                0.072180
# EVENTS                 0.062730
# EDUCATION              0.061817
# BEAUTY                 0.055729
# DATING                 0.054232
# FOOD_AND_DRINK         0.052371
# MEDICAL                0.046096
# SOCIAL                 0.024127
# AUTO_AND_VEHICLES      0.022652
# MAPS_AND_NAVIGATION    0.017970
# HOUSE_AND_HOME         0.016389
# WEATHER                0.011734
# SHOPPING               0.008161
# BUSINESS               0.005925
# VIDEO_PLAYERS          0.004356
# LIBRARIES_AND_DEMO     0.003274
# TRAVEL_AND_LOCAL       0.002556
# BOOKS_AND_REFERENCE    0.001881
# COMMUNICATION          0.000642
# NEWS_AND_MAGAZINES     0.000185
# ...

# %% [markdown]
# ##### 14. What is the distribution of app sizes in the top 3 categories with the most installs?

# %%
# Get top 3 categories with the most installs
top_3_categories_installs = play_store_df.groupby('Category')['Installs'].sum().nlargest(3).index.tolist()

# Calculate average app size for top 3 categories with most installs
average_size_top_3_categories = play_store_df[play_store_df['Category'].isin(top_3_categories_installs)].groupby('Category')['Size'].mean()
average_size_top_3_categories
# Out:
# Category
# COMMUNICATION    15.766202
# GAME             42.709791
# SOCIAL           19.630863
# Name: Size, dtype: float64

# %% [markdown]
# ##### 15. How does the average app size compare between free and paid apps?

# %%
# Calculate average app size for free apps

average_size_free_apps = play_store_df[play_store_df['Type'] == 'Free']['Size'].mean()
average_size_free_apps
# Out:
# 22.904386798999244

# %%
# calculate average app size for paid apps

average_size_paid_apps = play_store_df[play_store_df['Type'] == 'Paid']['Size'].mean()
average_size_paid_apps
# Out:
# 20.810354503375613

# %% [markdown]
# #### 4. Content and Genre Analysis

# %% [markdown]
# ##### 16. What are the most frequent sub-genres within the "Family" category?

# %%
# Count the most frequent sub-genres within the "Family" category

family_category = play_store_df[play_store_df['Category'] == 'FAMILY']
top_subgenres_family = family_category['Genres'].value_counts().head()
top_subgenres_family
# Out:
# Entertainment    397
# Education        340
# Simulation       183
# Casual           140
# Role Playing      90
# Name: Genres, dtype: int64

# %% [markdown]
# ##### 17. How does the content rating (e.g., Everyone, Teen) affect the number of installs?

# %%
# Calculate the average number of installs for each content rating category
average_installs_content_rating = play_store_df.groupby('Content_Rating')['Installs'].mean()
average_installs_content_rating
# Out:
# Content_Rating
# Adults only 18+    6.666667e+05
# Everyone           1.413776e+07
# Everyone 10+       3.108651e+07
# Mature 17+         1.043933e+07
# Teen               3.025250e+07
# Unrated            5.000000e+04
# Name: Installs, dtype: float64

# %% [markdown]
# ##### 18. Are there specific genres that consistently receive higher ratings?

# %%
# Calculate average ratings for each genre

average_ratings_per_genre = play_store_df.groupby('Genres')['Rating'].mean().sort_values(ascending=False)
average_ratings_per_genre.head()
# Out:
# Genres
# Comics;Creativity             4.8
# Board;Pretend Play            4.8
# Health & Fitness;Education    4.7
# Puzzle;Education              4.6
# Adventure;Brain Games         4.6
# Name: Rating, dtype: float64

# %% [markdown]
# ##### 19. How does the distribution of genres differ between free and paid apps?

# %%
# Calculate genre distribution for free and paid apps
# genre distribution for free apps

genre_distribution_free_apps = play_store_df[play_store_df['Type'] == 'Free']['Genres'].value_counts(normalize=True).head()
genre_distribution_free_apps
# Out:
# Tools            0.080846
# Entertainment    0.058610
# Education        0.051722
# Action           0.039275
# Productivity     0.038187
# Name: Genres, dtype: float64

# %%
# genre distribution for paid apps

genre_distribution_paid_apps = play_store_df[play_store_df['Type'] == 'Paid']['Genres'].value_counts(normalize=True).head()
genre_distribution_paid_apps
# Out:
# Personalization    0.106383
# Medical            0.104746
# Tools              0.103110
# Action             0.039280
# Communication      0.036007
# Name: Genres, dtype: float64

# %% [markdown]
# #### 6. Impact of Free vs. Paid Apps on Installs

# %% [markdown]
# ##### 22. How does the average number of installs differ between free and paid apps across different categories?

# %%
# How does the average number of installs differ between free and paid apps across different categories?

install_comparison = play_store_df.groupby(['Category', 'Type'])['Installs'].mean().unstack()
install_comparison['Install_Ratio'] = install_comparison['Paid'] / install_comparison['Free']
install_comparison_sorted = install_comparison.sort_values(by='Install_Ratio', ascending=False)

install_comparison_sorted
# Out:
# Type                         Free           Paid  Install_Ratio
# Category
# AUTO_AND_VEHICLES    7.372194e+05   50000.000000       0.067822
# MEDICAL              1.743915e+05   10273.437500       0.058910
# PARENTING            6.472085e+05   25050.000000       0.038705
# EDUCATION            4.266000e+06  150500.000000       0.035279
# LIFESTYLE            1.859101e+06   65506.111111       0.035235
# FAMILY               6.416624e+06  198393.821656       0.030919
# WEATHER              6.254191e+06  115928.571429       0.018536
# FOOD_AND_DRINK       2.478055e+06   30000.000000       0.012106
# SPORTS               5.785181e+06   56536.363636       0.009773
# GAME                 3.161762e+07  274016.389610       0.008667
# HEALTH_AND_FITNESS   5.420451e+06   43000.000000       0.007933
# PERSONALIZATION      8.518866e+06   65500.307692       0.007689
# BUSINESS             3.307684e+06   23628.888889       0.007144
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here
#
# ### Manipulations:
#
# 1. **Data Cleaning and Preparation:**
#    - Handled missing values, particularly in columns like `Rating`, `Size`, and `Type`.
#    - Converted data types to appropriate formats for analysis (e.g., converting sizes from string to numeric).
#    - Removed duplicates and irrelevant columns.
#
# 2. **Exploratory Data Analysis (EDA):**
#    - **Category Analysis:**
#      - Identified the top categories by the number of apps and installs.
#      - Analyzed the distribution of app ratings across categories.
#      - Explored the impact of app sizes on the number of installs.
#
#    - **Content and Genre Analysis:**
#      - Investigated the most popular sub-genres within the `Family` category.
#      - Explored how content ratings affect the number of installs.
#      - Examined whether certain genres consistently receive higher ratings.
#      - Compared the genre distribution between free and paid apps.
#
#    - **Free vs. Paid Apps Analysis:**
#      - Calculated the average app size for free and paid apps.
#      - Analyzed the install ratios between free and paid apps across different categories.
#
# ### Insights Found:
#
# 1. **Category Insights:**
#    - **Games and Tools** are the most populated categories in terms of the number of apps.
#    - **Communication, Game, and Social** categories lead in terms of the highest number of installs.
#    - **Tools, Entertainment, and Education** categories show a diverse range of app sizes, with Tools having the largest average size.
#
# 2. **Content and Genre Insights:**
#    - **Entertainment** and **Education** are dominant sub-genres within the `Family` category.
#    - **Everyone 10+** and **Teen** content ratings have significantly higher average installs compared to other ratings.
#
# 3. **Free vs. Paid Apps Insights:**
#    - Paid apps tend to have higher average ratings compared to free apps.
#    - Install ratios show varying trends across categories, suggesting potential niches for paid apps where users are willing to pay despite lower install numbers.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# 2. How does the number of apps vary across different categories?
# 3. What is the proportion of apps in each category relative to the total?
# 4. How does the distribution of app counts look across all categories?
# 5. What is the trend in app counts over the years in the dataset?
# 6. How do the top 10 categories compare in terms of app count growth over time?
# 7. What is the distribution of ratings within each category?
# 8. How does the average rating vary by category?
# 9. What is the relationship between the number of reviews and the average rating?
# 10. What is the impact of app size on the number of installs?
# 11. Are there any categories where larger apps (50MB+) are more popular based on installs?
# 12. What is the distribution of app sizes in the top 3 categories with the most installs?
# 13. How does the average app size compare between free and paid apps?
# 14. What are the most frequent sub-genres within the "Family" category?
# 15. How does the content rating (e.g., Everyone, Teen) affect the number of installs?
# 16. Are there specific genres that consistently receive higher ratings?
# 17. How does the distribution of genres differ between free and paid apps?
# 18. What are the least common genres in the dataset?
# 19. How does the average price of paid apps vary across categories?
# 20. How does the average number of installs differ between free and paid apps across different categories?

# %% [markdown]
# #### Chart - 1

# %%
# Count the number of apps in each category
category_counts = play_store_df['Category'].value_counts()

# Visualize the number of apps in each category
fig = visualize_chart(plot_functions['bar'], 
                      title='Number of Apps by Category', 
                      xlabel='Category', 
                      ylabel='Number of Apps', 
                      x=category_counts.index, 
                      y=category_counts.values)
plt.tight_layout()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# A bar chart is chosen to show the number of apps across different categories as it effectively displays categorical data and makes it easy to compare the app counts across categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The chart shows the distribution of apps across various categories, highlighting which categories have the highest and lowest number of apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Yes, understanding which categories have the most apps can help identify market saturation and opportunities for app development in less crowded categories.

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# # **Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
